# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# ## Video segmentation and tracking with SAM 3
#
# This notebook demonstrates how to use SAM 3 for interactive video segmentation and dense tracking. It covers the following capabilities:
#
# - **Text prompts**: Using natural language descriptions to segment objects (e.g., "person", "shoe")
# - **Point prompts**: Adding positive/negative clicks to segment and refine objects
#
# We use the terms _segment_ or _mask_ to refer to the model prediction for an object on a single frame, and _masklet_ to refer to the spatio-temporal masks across the entire video.

# %% [markdown]
# ## Set-up
#
# In this example, we allow running inference either on a single GPU or multiple GPUs.

# %%
import os
import sam3
import torch

sam3_root = os.path.join(os.path.dirname(sam3.__file__), "..")

# use all available GPUs on the machine
# gpus_to_use = range(torch.cuda.device_count())
# # use only a single GPU
# gpus_to_use = [torch.cuda.current_device()]
gpus_to_use = [1]
# Out:
# /home/prince/proj/chicken-behaviour-classifier/sam3/sam3/model_builder.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
from sam3.model_builder import build_sam3_video_predictor

# %%
predictor = build_sam3_video_predictor(gpus_to_use=gpus_to_use)
# Out:
# INFO 2026-01-19 16:57:28,927 1007785 sam3_video_predictor.py: 300: using the following GPU IDs: [1]
# INFO 2026-01-19 16:57:29,159 1007785 sam3_video_predictor.py: 316:
#
#
# 	*** START loading model on all ranks ***
#
#
# INFO 2026-01-19 16:57:29,160 1007785 sam3_video_predictor.py: 318: loading model on rank=0 with world_size=1 -- this could take a while ...
# INFO 2026-01-19 16:57:34,610 1007785 sam3_video_base.py: 125: setting max_num_objects=10000 and num_obj_for_compile=16
# INFO 2026-01-19 16:57:37,421 1007785 sam3_video_predictor.py: 320: loading model on rank=0 with world_size=1 -- DONE locally
# INFO 2026-01-19 16:57:37,422 1007785 sam3_video_predictor.py: 331:
#
#
# 	*** DONE loading model on all ranks ***

# %% [markdown]
# #### Inference and visualization utils

# %%
import glob
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from sam3.visualization_utils import (
    load_frame,
    prepare_masks_for_visualization,
    visualize_formatted_frame_output,
)

# font size for axes titles
plt.rcParams["axes.titlesize"] = 12
plt.rcParams["figure.titlesize"] = 12


def propagate_in_video(predictor, session_id):
    # we will just propagate from frame 0 to the end of the video
    outputs_per_frame = {}
    for response in predictor.handle_stream_request(
        request=dict(
            type="propagate_in_video",
            session_id=session_id,
        )
    ):
        outputs_per_frame[response["frame_index"]] = response["outputs"]

    return outputs_per_frame


def abs_to_rel_coords(coords, IMG_WIDTH, IMG_HEIGHT, coord_type="point"):
    """Convert absolute coordinates to relative coordinates (0-1 range)

    Args:
        coords: List of coordinates
        coord_type: 'point' for [x, y] or 'box' for [x, y, w, h]
    """
    if coord_type == "point":
        return [[x / IMG_WIDTH, y / IMG_HEIGHT] for x, y in coords]
    elif coord_type == "box":
        return [
            [x / IMG_WIDTH, y / IMG_HEIGHT, w / IMG_WIDTH, h / IMG_HEIGHT]
            for x, y, w, h in coords
        ]
    else:
        raise ValueError(f"Unknown coord_type: {coord_type}")

# %% [markdown]
# ### Loading an example video
#
# We assume that the video is stored as either **a list of JPEG frames with filenames like `<frame_index>.jpg`** or **an MP4 video**.
#
# Note that you can extract their JPEG frames using ffmpeg (https://ffmpeg.org/) as follows:
# ```
# ffmpeg -i <your_video>.mp4 -q:v 2 -start_number 0 <output_dir>/'%05d.jpg'
# ```
# where `-q:v` generates high-quality JPEG frames and `-start_number 0` asks ffmpeg to start the JPEG file from `00000.jpg`.

# %%
# "video_path" needs to be either a JPEG folder or a MP4 video file
# video_path = f"{sam3_root}/assets/videos/0001"
# video_path = "/home/prince/proj/chicken-behaviour-classifier/data/test.mp4"
video_path = "/home/prince/proj/chicken-behaviour-classifier/data/test_15_sec.mp4"

# %%
# load "video_frames_for_vis" for visualization purposes (they are not used by the model)
if isinstance(video_path, str) and video_path.endswith(".mp4"):
    cap = cv2.VideoCapture(video_path)
    video_frames_for_vis = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        video_frames_for_vis.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    cap.release()
else:
    video_frames_for_vis = glob.glob(os.path.join(video_path, "*.jpg"))
    try:
        # integer sort instead of string sort (so that e.g. "2.jpg" is before "11.jpg")'
        video_frames_for_vis.sort(
            key=lambda p: int(os.path.splitext(os.path.basename(p))[0])
        )
    except ValueError:
        # fallback to lexicographic sort if the format is not "<frame_index>.jpg"
        print(
            f'frame names are not in "<frame_index>.jpg" format: {video_frames_for_vis[:5]=}, '
            f"falling back to lexicographic sort."
        )
        video_frames_for_vis.sort()

# %%
frame_idx = 0
sample_img = Image.fromarray(load_frame(video_frames_for_vis[frame_idx]))

IMG_WIDTH, IMG_HEIGHT = sample_img.size

# %% [markdown]
# ### Opening an inference session on this video
#
# SAM 3 requires stateful inference for interactive video segmentation, so we need to initialize an **inference session** on this video.
#
# During initialization, it loads all the video frames and stores their pixels in the session state.

# %%
response = predictor.handle_request(
    request=dict(
        type="start_session",
        resource_path=video_path,
    )
)
session_id = response["session_id"]
# Out:
# frame loading (OpenCV) [rank=0]: 100%|██████████| 374/374 [00:00<00:00, 974.30it/s]

# %%
def add_point(obj_id, xy):
    pts = np.array([xy])
    labels = np.array([1])
    pts_rel = abs_to_rel_coords(pts, IMG_WIDTH, IMG_HEIGHT)

    return predictor.handle_request({
        "type": "add_prompt",
        "session_id": session_id,
        "frame_index": frame_idx,
        "points": torch.tensor(pts_rel, dtype=torch.float32),
        "point_labels": torch.tensor(labels, dtype=torch.int32),
        "obj_id": obj_id,
    })

# %% [markdown]
# ### Video promptable concept segmentation with text
#
# Using SAM 3 you can describe objects using natural language, and the model will automatically detect and track all instances of that object throughout the video.
#
# In the example below, we add a text prompt on frame 0 and propagation throughout the video. Here we use the text prompt "person" to detect all people in the video. SAM 3 will automatically identify multiple person instances and assign each a unique object ID.
#
# Note that the first call might be slower due to setting up buffers. **You can rerun all the cells below when measuring speed.**

# %%
# note: in case you already ran one text prompt and now want to switch to another text prompt
# it's required to reset the session first (otherwise the results would be wrong)
# _ = predictor.handle_request(
#     request=dict(
#         type="reset_session",
#         session_id=session_id,
#     )
# )

# %%
response = predictor.handle_request(
    request=dict(type="add_prompt", session_id=session_id, frame_index=frame_idx, text="bird")
)

out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
)

# %%
response = add_point(0, (510, 490))
out = response["outputs"]
plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
)

# %%
response = add_point(1, (530, 450))
out = response["outputs"]
plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
)

# %%
response = add_point(2, (570, 460))
out = response["outputs"]
plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
)

# %%
outputs_per_frame = propagate_in_video(predictor, session_id)
# Out:
#   0%|          | 0/374 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 outputs_per_frame = propagate_in_video(predictor, session_id)
#
# Cell In[5], line 22, in propagate_in_video(predictor, session_id)
#      19 def propagate_in_video(predictor, session_id):
#      20     # we will just propagate from frame 0 to the end of the video
#      21     outputs_per_frame = {}
# ---> 22     for response in predictor.handle_stream_request(
#      23         request=dict(
#      24             type="propagate_in_video",
#      25             session_id=session_id,
#      26         )
#      27     ):
#      28         outputs_per_frame[response["frame_index"]] = response["outputs"]
#      30     return outputs_per_frame
#
# File ~/miniforge3/envs/sam3-torchcodec/lib/python3.12/site-packages/torch/utils/_contextlib.py:59, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      56         else:
#      57             # Pass the last request to the generator and get its response
#      58             with ctx_factory():
# ---> 59                 response = gen.send(request)
#      61 # We let the exceptions raised above by the generator's `.throw` or
#      62 # `.send` methods bubble up to our caller, except for StopIteration
#      63 except StopIteration as e:
#      64     # The generator informed us that it is done: take whatever its
#      65     # returned value (if any) was and indicate that we're done too
#      66     # by returning it (see docs for python's return-statement).
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_predictor.py:369, in Sam3VideoPredictorMultiGPU.handle_stream_request(self, request)
#     366     for rank in range(1, self.world_size):
#     367         self.command_queues[rank].put((request, True))
# --> 369 yield from super().handle_stream_request(request)
#     371 if self.world_size > 1:
#     372     torch.distributed.barrier()
#
# File ~/miniforge3/envs/sam3-torchcodec/lib/python3.12/site-packages/torch/utils/_contextlib.py:59, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      56         else:
#      57             # Pass the last request to the generator and get its response
#      58             with ctx_factory():
# ---> 59                 response = gen.send(request)
#      61 # We let the exceptions raised above by the generator's `.throw` or
#      62 # `.send` methods bubble up to our caller, except for StopIteration
#      63 except StopIteration as e:
#      64     # The generator informed us that it is done: take whatever its
#      65     # returned value (if any) was and indicate that we're done too
#      66     # by returning it (see docs for python's return-statement).
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_predictor.py:94, in Sam3VideoPredictor.handle_stream_request(self, request)
#      92 request_type = request["type"]
#      93 if request_type == "propagate_in_video":
# ---> 94     yield from self.propagate_in_video(
#      95         session_id=request["session_id"],
#      96         propagation_direction=request.get("propagation_direction", "both"),
#      97         start_frame_idx=request.get("start_frame_index", None),
#      98         max_frame_num_to_track=request.get("max_frame_num_to_track", None),
#      99     )
#     100 else:
#     101     raise RuntimeError(f"invalid request type: {request_type}")
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_predictor.py:206, in Sam3VideoPredictor.propagate_in_video(self, session_id, propagation_direction, start_frame_idx, max_frame_num_to_track)
#     204 # First doing the forward propagation
#     205 if propagation_direction in ["both", "forward"]:
# --> 206     for frame_idx, outputs in self.model.propagate_in_video(
#     207         inference_state=inference_state,
#     208         start_frame_idx=start_frame_idx,
#     209         max_frame_num_to_track=max_frame_num_to_track,
#     210         reverse=False,
#     211     ):
#     212         yield {"frame_index": frame_idx, "outputs": outputs}
#     213 # Then doing the backward propagation (reverse in time)
#
# File ~/miniforge3/envs/sam3-torchcodec/lib/python3.12/site-packages/torch/utils/_contextlib.py:59, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      56         else:
#      57             # Pass the last request to the generator and get its response
#      58             with ctx_factory():
# ---> 59                 response = gen.send(request)
#      61 # We let the exceptions raised above by the generator's `.throw` or
#      62 # `.send` methods bubble up to our caller, except for StopIteration
#      63 except StopIteration as e:
#      64     # The generator informed us that it is done: take whatever its
#      65     # returned value (if any) was and indicate that we're done too
#      66     # by returning it (see docs for python's return-statement).
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_inference.py:1160, in Sam3VideoInferenceWithInstanceInteractivity.propagate_in_video(self, inference_state, start_frame_idx, max_frame_num_to_track, reverse)
#    1153     refined_mask_video_res = (
#    1154         self._convert_low_res_mask_to_video_res(
#    1155             refined_mask_low_res, inference_state
#    1156         )
#    1157     )  # (1, H_video, W_video) bool
#    1158     refined_obj_id_to_mask[obj_id] = refined_mask_video_res
# -> 1160 obj_id_to_mask = self._build_tracker_output(
#    1161     inference_state, frame_idx, refined_obj_id_to_mask
#    1162 )
#    1163 out = {
#    1164     "obj_id_to_mask": obj_id_to_mask,
#    1165     "obj_id_to_score": tracker_metadata["obj_id_to_score"],
#    (...)   1168     ][frame_idx],
#    1169 }
#    1170 suppressed_obj_ids = tracker_metadata["rank0_metadata"][
#    1171     "suppressed_obj_ids"
#    1172 ][frame_idx]
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_inference.py:555, in Sam3VideoInference._build_tracker_output(self, inference_state, frame_idx, refined_obj_id_to_mask)
#     551 def _build_tracker_output(
#     552     self, inference_state, frame_idx, refined_obj_id_to_mask=None
#     553 ):
#     554     assert (
# --> 555         "cached_frame_outputs" in inference_state
#     556         and frame_idx in inference_state["cached_frame_outputs"]
#     557     ), (
#     558         "No cached outputs found. Ensure normal propagation has run first to populate the cache."
#     559     )
#     560     cached_outputs = inference_state["cached_frame_outputs"][frame_idx]
#     562     obj_id_to_mask = cached_outputs.copy()
#
# AssertionError: No cached outputs found. Ensure normal propagation has run first to populate the cache.

# %% [markdown]
# ***

# %%
# prompt_text_str = "black and white chicken"
prompt_text_str = "bird"
frame_idx = 0  # add a text prompt on frame 


# 2) add separate text prompts (PCS)
# response = predictor.handle_request(
#     request=dict(type="add_prompt", session_id=session_id, frame_index=frame_idx, text="chicken")
# )
# response = predictor.handle_request(
#     request=dict(type="add_prompt", session_id=session_id, frame_index=frame_idx, text="bird")
# )
response = predictor.handle_request(
    request=dict(type="add_prompt", session_id=session_id, frame_index=frame_idx, text=prompt_text_str)
)

out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
)

# %% [markdown]
# ***

# %%
frame_idx = 0
sample_img = Image.fromarray(load_frame(video_frames_for_vis[frame_idx]))

IMG_WIDTH, IMG_HEIGHT = sample_img.size

# let's add back the dancer via point prompts.
# we will use a single positive click to add the dancer back.

obj_id = 0
points_abs = np.array(
    [
        [530, 450],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1])

# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
frame_idx = 0
sample_img = Image.fromarray(load_frame(video_frames_for_vis[frame_idx]))

IMG_WIDTH, IMG_HEIGHT = sample_img.size

# object 0 
pts_0 = np.array([[510, 490]])
labels_0 = np.array([1])  # 2 positive, 1 negative

out_0 = predictor.handle_request(
    dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=torch.tensor(abs_to_rel_coords(pts_0, IMG_WIDTH, IMG_HEIGHT),
                            dtype=torch.float32),
        point_labels=torch.tensor(labels_0, dtype=torch.int32),
        obj_id=0,
    )
)["outputs"]

# object 1 
pts_1 = np.array([[530, 450]])
labels_1 = np.array([1])

out_1 = predictor.handle_request(
    dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=torch.tensor(abs_to_rel_coords(pts_1, IMG_WIDTH, IMG_HEIGHT),
                            dtype=torch.float32),
        point_labels=torch.tensor(labels_1, dtype=torch.int32),
        obj_id=1,
    )
)["outputs"]

# object 2
pts_2 = np.array([[570, 460]])
labels_2 = np.array([1])

out_2 = predictor.handle_request(
    dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=torch.tensor(abs_to_rel_coords(pts_2, IMG_WIDTH, IMG_HEIGHT),
                            dtype=torch.float32),
        point_labels=torch.tensor(labels_1, dtype=torch.int32),
        obj_id=2,
    )
)["outputs"]

# %%
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[
        prepare_masks_for_visualization({frame_idx: out_0}),
        prepare_masks_for_visualization({frame_idx: out_1}),
        prepare_masks_for_visualization({frame_idx: out_2}),
    ],
    # titles=["All point prompts combined"],
    points_list=[pts_0, pts_1, pts_2],
    points_labels_list=[labels_0, labels_1, labels_2],
    figsize=(7, 5),
)

# %%
# propagate all frames
outputs_per_frame = propagate_in_video(predictor, session_id)

# convert raw masks → visualization-ready form
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

# visualize every 25th frame
vis_frame_stride = 25
plt.close("all")

for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[{frame_idx: outputs_per_frame[frame_idx]}],
        titles=[f"SAM 3 Dense Tracking outputs (frame {frame_idx})"],
        figsize=(6, 4),
    )
# Out:
#   0%|          | 0/374 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 # propagate all frames
# ----> 2 outputs_per_frame = propagate_in_video(predictor, session_id)
#       4 # convert raw masks → visualization-ready form
#       5 outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)
#
# Cell In[4], line 22, in propagate_in_video(predictor, session_id)
#      19 def propagate_in_video(predictor, session_id):
#      20     # we will just propagate from frame 0 to the end of the video
#      21     outputs_per_frame = {}
# ---> 22     for response in predictor.handle_stream_request(
#      23         request=dict(
#      24             type="propagate_in_video",
#      25             session_id=session_id,
#      26         )
#      27     ):
#      28         outputs_per_frame[response["frame_index"]] = response["outputs"]
#      30     return outputs_per_frame
#
# File ~/miniforge3/envs/sam3-torchcodec/lib/python3.12/site-packages/torch/utils/_contextlib.py:59, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      56         else:
#      57             # Pass the last request to the generator and get its response
#      58             with ctx_factory():
# ---> 59                 response = gen.send(request)
#      61 # We let the exceptions raised above by the generator's `.throw` or
#      62 # `.send` methods bubble up to our caller, except for StopIteration
#      63 except StopIteration as e:
#      64     # The generator informed us that it is done: take whatever its
#      65     # returned value (if any) was and indicate that we're done too
#      66     # by returning it (see docs for python's return-statement).
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_predictor.py:369, in Sam3VideoPredictorMultiGPU.handle_stream_request(self, request)
#     366     for rank in range(1, self.world_size):
#     367         self.command_queues[rank].put((request, True))
# --> 369 yield from super().handle_stream_request(request)
#     371 if self.world_size > 1:
#     372     torch.distributed.barrier()
#
# File ~/miniforge3/envs/sam3-torchcodec/lib/python3.12/site-packages/torch/utils/_contextlib.py:59, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      56         else:
#      57             # Pass the last request to the generator and get its response
#      58             with ctx_factory():
# ---> 59                 response = gen.send(request)
#      61 # We let the exceptions raised above by the generator's `.throw` or
#      62 # `.send` methods bubble up to our caller, except for StopIteration
#      63 except StopIteration as e:
#      64     # The generator informed us that it is done: take whatever its
#      65     # returned value (if any) was and indicate that we're done too
#      66     # by returning it (see docs for python's return-statement).
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_predictor.py:94, in Sam3VideoPredictor.handle_stream_request(self, request)
#      92 request_type = request["type"]
#      93 if request_type == "propagate_in_video":
# ---> 94     yield from self.propagate_in_video(
#      95         session_id=request["session_id"],
#      96         propagation_direction=request.get("propagation_direction", "both"),
#      97         start_frame_idx=request.get("start_frame_index", None),
#      98         max_frame_num_to_track=request.get("max_frame_num_to_track", None),
#      99     )
#     100 else:
#     101     raise RuntimeError(f"invalid request type: {request_type}")
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_predictor.py:206, in Sam3VideoPredictor.propagate_in_video(self, session_id, propagation_direction, start_frame_idx, max_frame_num_to_track)
#     204 # First doing the forward propagation
#     205 if propagation_direction in ["both", "forward"]:
# --> 206     for frame_idx, outputs in self.model.propagate_in_video(
#     207         inference_state=inference_state,
#     208         start_frame_idx=start_frame_idx,
#     209         max_frame_num_to_track=max_frame_num_to_track,
#     210         reverse=False,
#     211     ):
#     212         yield {"frame_index": frame_idx, "outputs": outputs}
#     213 # Then doing the backward propagation (reverse in time)
#
# File ~/miniforge3/envs/sam3-torchcodec/lib/python3.12/site-packages/torch/utils/_contextlib.py:59, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      56         else:
#      57             # Pass the last request to the generator and get its response
#      58             with ctx_factory():
# ---> 59                 response = gen.send(request)
#      61 # We let the exceptions raised above by the generator's `.throw` or
#      62 # `.send` methods bubble up to our caller, except for StopIteration
#      63 except StopIteration as e:
#      64     # The generator informed us that it is done: take whatever its
#      65     # returned value (if any) was and indicate that we're done too
#      66     # by returning it (see docs for python's return-statement).
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_inference.py:1160, in Sam3VideoInferenceWithInstanceInteractivity.propagate_in_video(self, inference_state, start_frame_idx, max_frame_num_to_track, reverse)
#    1153     refined_mask_video_res = (
#    1154         self._convert_low_res_mask_to_video_res(
#    1155             refined_mask_low_res, inference_state
#    1156         )
#    1157     )  # (1, H_video, W_video) bool
#    1158     refined_obj_id_to_mask[obj_id] = refined_mask_video_res
# -> 1160 obj_id_to_mask = self._build_tracker_output(
#    1161     inference_state, frame_idx, refined_obj_id_to_mask
#    1162 )
#    1163 out = {
#    1164     "obj_id_to_mask": obj_id_to_mask,
#    1165     "obj_id_to_score": tracker_metadata["obj_id_to_score"],
#    (...)   1168     ][frame_idx],
#    1169 }
#    1170 suppressed_obj_ids = tracker_metadata["rank0_metadata"][
#    1171     "suppressed_obj_ids"
#    1172 ][frame_idx]
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_inference.py:555, in Sam3VideoInference._build_tracker_output(self, inference_state, frame_idx, refined_obj_id_to_mask)
#     551 def _build_tracker_output(
#     552     self, inference_state, frame_idx, refined_obj_id_to_mask=None
#     553 ):
#     554     assert (
# --> 555         "cached_frame_outputs" in inference_state
#     556         and frame_idx in inference_state["cached_frame_outputs"]
#     557     ), (
#     558         "No cached outputs found. Ensure normal propagation has run first to populate the cache."
#     559     )
#     560     cached_outputs = inference_state["cached_frame_outputs"][frame_idx]
#     562     obj_id_to_mask = cached_outputs.copy()
#
# AssertionError: No cached outputs found. Ensure normal propagation has run first to populate the cache.

# %% [markdown]
# ***

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 25
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )
# Out:
# propagate_in_video:   0%|          | 0/274 [00:00<?, ?it/s]
# propagate_in_video:   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# ###  Removing objects
#
# We can remove individual objects using their id.
#
# As an example, let's remove object 2 (which is the dancer in the front).

# %%
# we pick id 2, which is the dancer in the front
obj_id = 2
response = predictor.handle_request(
    request=dict(
        type="remove_object",
        session_id=session_id,
        obj_id=obj_id,
    )
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 25
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Adding new objects with point prompts
#
# We can add new objects through point prompts.
#
# Assuming that we've changed our mind, and now that we want to add back the dancer in the front (whom we just removed in the step above). We can use interactive clicks to add her back.

# %%
# sample_img = Image.fromarray(load_frame(video_frames_for_vis[0]))
frame_idx = 100
sample_img = Image.fromarray(load_frame(video_frames_for_vis[frame_idx]))

IMG_WIDTH, IMG_HEIGHT = sample_img.size

# %%
# let's add back the dancer via point prompts.
# we will use a single positive click to add the dancer back.

# frame_idx = 100
obj_id = 2
points_abs = np.array(
    [
        [530, 450],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 25
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )
# Out:
#   0%|          | 0/274 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[49], line 2
#       1 # now we propagate the outputs from frame 0 to the end of the video and collect all outputs
# ----> 2 outputs_per_frame = propagate_in_video(predictor, session_id)
#       4 # finally, we reformat the outputs for visualization and plot the outputs every 60 frames
#       5 outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)
#
# Cell In[17], line 22, in propagate_in_video(predictor, session_id)
#      19 def propagate_in_video(predictor, session_id):
#      20     # we will just propagate from frame 0 to the end of the video
#      21     outputs_per_frame = {}
# ---> 22     for response in predictor.handle_stream_request(
#      23         request=dict(
#      24             type="propagate_in_video",
#      25             session_id=session_id,
#      26         )
#      27     ):
#      28         outputs_per_frame[response["frame_index"]] = response["outputs"]
#      30     return outputs_per_frame
#
# File ~/miniforge3/envs/sam3-torchcodec/lib/python3.12/site-packages/torch/utils/_contextlib.py:59, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      56         else:
#      57             # Pass the last request to the generator and get its response
#      58             with ctx_factory():
# ---> 59                 response = gen.send(request)
#      61 # We let the exceptions raised above by the generator's `.throw` or
#      62 # `.send` methods bubble up to our caller, except for StopIteration
#      63 except StopIteration as e:
#      64     # The generator informed us that it is done: take whatever its
#      65     # returned value (if any) was and indicate that we're done too
#      66     # by returning it (see docs for python's return-statement).
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_predictor.py:369, in Sam3VideoPredictorMultiGPU.handle_stream_request(self, request)
#     366     for rank in range(1, self.world_size):
#     367         self.command_queues[rank].put((request, True))
# --> 369 yield from super().handle_stream_request(request)
#     371 if self.world_size > 1:
#     372     torch.distributed.barrier()
#
# File ~/miniforge3/envs/sam3-torchcodec/lib/python3.12/site-packages/torch/utils/_contextlib.py:59, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      56         else:
#      57             # Pass the last request to the generator and get its response
#      58             with ctx_factory():
# ---> 59                 response = gen.send(request)
#      61 # We let the exceptions raised above by the generator's `.throw` or
#      62 # `.send` methods bubble up to our caller, except for StopIteration
#      63 except StopIteration as e:
#      64     # The generator informed us that it is done: take whatever its
#      65     # returned value (if any) was and indicate that we're done too
#      66     # by returning it (see docs for python's return-statement).
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_predictor.py:94, in Sam3VideoPredictor.handle_stream_request(self, request)
#      92 request_type = request["type"]
#      93 if request_type == "propagate_in_video":
# ---> 94     yield from self.propagate_in_video(
#      95         session_id=request["session_id"],
#      96         propagation_direction=request.get("propagation_direction", "both"),
#      97         start_frame_idx=request.get("start_frame_index", None),
#      98         max_frame_num_to_track=request.get("max_frame_num_to_track", None),
#      99     )
#     100 else:
#     101     raise RuntimeError(f"invalid request type: {request_type}")
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_predictor.py:206, in Sam3VideoPredictor.propagate_in_video(self, session_id, propagation_direction, start_frame_idx, max_frame_num_to_track)
#     204 # First doing the forward propagation
#     205 if propagation_direction in ["both", "forward"]:
# --> 206     for frame_idx, outputs in self.model.propagate_in_video(
#     207         inference_state=inference_state,
#     208         start_frame_idx=start_frame_idx,
#     209         max_frame_num_to_track=max_frame_num_to_track,
#     210         reverse=False,
#     211     ):
#     212         yield {"frame_index": frame_idx, "outputs": outputs}
#     213 # Then doing the backward propagation (reverse in time)
#
# File ~/miniforge3/envs/sam3-torchcodec/lib/python3.12/site-packages/torch/utils/_contextlib.py:59, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      56         else:
#      57             # Pass the last request to the generator and get its response
#      58             with ctx_factory():
# ---> 59                 response = gen.send(request)
#      61 # We let the exceptions raised above by the generator's `.throw` or
#      62 # `.send` methods bubble up to our caller, except for StopIteration
#      63 except StopIteration as e:
#      64     # The generator informed us that it is done: take whatever its
#      65     # returned value (if any) was and indicate that we're done too
#      66     # by returning it (see docs for python's return-statement).
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_inference.py:1160, in Sam3VideoInferenceWithInstanceInteractivity.propagate_in_video(self, inference_state, start_frame_idx, max_frame_num_to_track, reverse)
#    1153     refined_mask_video_res = (
#    1154         self._convert_low_res_mask_to_video_res(
#    1155             refined_mask_low_res, inference_state
#    1156         )
#    1157     )  # (1, H_video, W_video) bool
#    1158     refined_obj_id_to_mask[obj_id] = refined_mask_video_res
# -> 1160 obj_id_to_mask = self._build_tracker_output(
#    1161     inference_state, frame_idx, refined_obj_id_to_mask
#    1162 )
#    1163 out = {
#    1164     "obj_id_to_mask": obj_id_to_mask,
#    1165     "obj_id_to_score": tracker_metadata["obj_id_to_score"],
#    (...)   1168     ][frame_idx],
#    1169 }
#    1170 suppressed_obj_ids = tracker_metadata["rank0_metadata"][
#    1171     "suppressed_obj_ids"
#    1172 ][frame_idx]
#
# File ~/proj/chicken-behaviour-classifier/sam3/sam3/model/sam3_video_inference.py:555, in Sam3VideoInference._build_tracker_output(self, inference_state, frame_idx, refined_obj_id_to_mask)
#     551 def _build_tracker_output(
#     552     self, inference_state, frame_idx, refined_obj_id_to_mask=None
#     553 ):
#     554     assert (
# --> 555         "cached_frame_outputs" in inference_state
#     556         and frame_idx in inference_state["cached_frame_outputs"]
#     557     ), (
#     558         "No cached outputs found. Ensure normal propagation has run first to populate the cache."
#     559     )
#     560     cached_outputs = inference_state["cached_frame_outputs"][frame_idx]
#     562     obj_id_to_mask = cached_outputs.copy()
#
# AssertionError: No cached outputs found. Ensure normal propagation has run first to populate the cache.

# %% [markdown]
# ### Refining an existing object with point prompts
#
# We can also refine the segmentation mask of an existing object through point prompts.
#
# Assuming that we've changed our mind (again) -- for Object ID 2 (the dancer in the front whom we just added back in the step above), now we only want to segment her T-shirt instead of her whole body. We can adjust the segmentation mask with a few more positive and negative clicks.

# %%
# For the dancer in the front, suppose now we only want to segment her T-shirt instead of her whole body
# we will use 2 positive clicks and 2 negative clicks to select her shirt.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [740, 450],  # positive click
        [760, 630],  # negative click
        [840, 640],  # negative click
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1, 0, 0, 1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Close session
#
# Each session is tied to a single video. We can close the session after inference to free up its resources.
#
# (Then, you may start a new session on another video.)

# %%
# finally, close the inference session to free its GPU resources
# (you may start a new session on another video)
_ = predictor.handle_request(
    request=dict(
        type="close_session",
        session_id=session_id,
    )
)
# Out:
# INFO 2026-01-19 16:39:11,945 961067 sam3_video_predictor.py: 251: removed session 39bf9753-1b13-4327-a10e-3bd8667c39fb; live sessions: [], GPU memory: 9764 MiB used and 10724 MiB reserved (max over time: 10332 MiB used and 10724 MiB reserved)

# %% [markdown]
# ### Clean-up
#
# After all inference is done, we can shutdown the predictor to free up the multi-GPU process group.

# %%
# after all inference is done, we can shutdown the predictor
# to free up the multi-GPU process group
predictor.shutdown()
